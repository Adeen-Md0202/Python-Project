# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Data=pd.read_excel('airdata.xlsx')
Data
# Out:
#         Host Id Host Since                                Name Neighbourhood   \
# 0       5162530        NaT     1 Bedroom in Prime Williamsburg       Brooklyn
# 1      33134899        NaT     Sunny, Private room in Bushwick       Brooklyn
# 2      39608626        NaT                Sunny Room in Harlem      Manhattan
# 3           500 2008-06-26  Gorgeous 1 BR with Private Balcony      Manhattan
# 4           500 2008-06-26            Trendy Times Square Loft      Manhattan
# ...         ...        ...                                 ...            ...
# 30473  43022976 2015-08-31   10 Mins to Time Square/two floors         Queens
# 30474  42993382 2015-08-31       1BR ocean view & F,Q train st       Brooklyn
# 30475  43033067 2015-08-31                Amazing Private Room       Brooklyn
# 30476  43000991 2015-08-31   Charming private female room: UWS      Manhattan
# 30477  42999189 2015-08-31    Huge Beautiful Bedroom - Astoria         Queens
#
# ...

# %%
Data.head(100)
# Out:
#      Host Id Host Since                                 Name Neighbourhood   \
# 0    5162530        NaT      1 Bedroom in Prime Williamsburg       Brooklyn
# 1   33134899        NaT      Sunny, Private room in Bushwick       Brooklyn
# 2   39608626        NaT                 Sunny Room in Harlem      Manhattan
# 3        500 2008-06-26   Gorgeous 1 BR with Private Balcony      Manhattan
# 4        500 2008-06-26             Trendy Times Square Loft      Manhattan
# ..       ...        ...                                  ...            ...
# 95      8198 2009-02-19   Park Slope haven 15 mins from Soho       Brooklyn
# 96      8380 2009-02-22            River view in the Village      Manhattan
# 97      8440 2009-02-23    Beautiful studio by Prospect Park       Brooklyn
# 98      8440 2009-02-23  Luxe 1BD apartment by Prospect Park       Brooklyn
# 99      8425 2009-02-23    Charming W.Village Apt. 8/25-9/15      Manhattan
#
# ...

# %%
Data.tail(100)
# Out:
#         Host Id Host Since                                Name Neighbourhood   \
# 30378  42518458 2015-08-25  Williamsburg Luxury Loft!⭐️Bed Top       Brooklyn
# 30379  42489546 2015-08-25    Sofa bed in spacious living room      Manhattan
# 30380  42619297 2015-08-26  Clinton Hill -  Large Brooklyn Pad       Brooklyn
# 30381  42579138 2015-08-26     Upscale apt w/ loft (1200 sqft)      Manhattan
# 30382  42577546 2015-08-26        Spacious East Village Studio      Manhattan
# ...         ...        ...                                 ...            ...
# 30473  43022976 2015-08-31   10 Mins to Time Square/two floors         Queens
# 30474  42993382 2015-08-31       1BR ocean view & F,Q train st       Brooklyn
# 30475  43033067 2015-08-31                Amazing Private Room       Brooklyn
# 30476  43000991 2015-08-31   Charming private female room: UWS      Manhattan
# 30477  42999189 2015-08-31    Huge Beautiful Bedroom - Astoria         Queens
#
# ...

# %%
Data.isnull().sum()
# Out:
# Host Id                          0
# Host Since                       3
# Name                             0
# Neighbourhood                    0
# Property Type                    3
# Review Scores Rating (bin)    8323
# Room Type                        0
# Zipcode                        134
# Beds                            85
# Number of Records                0
# Number Of Reviews                0
# Price                            0
# Review Scores Rating          8323
# dtype: int64

# %%
data = Data.fillna(0)

# %%
data
# Out:
#         Host Id           Host Since                                Name  \
# 0       5162530                    0     1 Bedroom in Prime Williamsburg
# 1      33134899                    0     Sunny, Private room in Bushwick
# 2      39608626                    0                Sunny Room in Harlem
# 3           500  2008-06-26 00:00:00  Gorgeous 1 BR with Private Balcony
# 4           500  2008-06-26 00:00:00            Trendy Times Square Loft
# ...         ...                  ...                                 ...
# 30473  43022976  2015-08-31 00:00:00   10 Mins to Time Square/two floors
# 30474  42993382  2015-08-31 00:00:00       1BR ocean view & F,Q train st
# 30475  43033067  2015-08-31 00:00:00                Amazing Private Room
# 30476  43000991  2015-08-31 00:00:00   Charming private female room: UWS
# 30477  42999189  2015-08-31 00:00:00    Huge Beautiful Bedroom - Astoria
#
#       Neighbourhood  Property Type  Review Scores Rating (bin)  \
# ...

# %%
data = data.fillna(0)

# %%
data = data.replace("empty",0)

# %%
data =pd.DataFrame(data)
print(data.shape)
# Out:
# (30478, 13)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30478 entries, 0 to 30477
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Host Id                     30478 non-null  int64
#  1   Host Since                  30478 non-null  object
#  2   Name                        30478 non-null  object
#  3   Neighbourhood               30478 non-null  object
#  4   Property Type               30478 non-null  object
#  5   Review Scores Rating (bin)  30478 non-null  float64
#  6   Room Type                   30478 non-null  object
#  7   Zipcode                     30478 non-null  float64
#  8   Beds                        30478 non-null  float64
#  9   Number of Records           30478 non-null  int64
#  10  Number Of Reviews           30478 non-null  int64
#  11  Price                       30478 non-null  int64
#  12  Review Scores Rating        30478 non-null  float64
# ...

# %%
data.describe()
# Out:
#             Host Id  Review Scores Rating (bin)       Zipcode          Beds  \
# count  3.047800e+04                30478.000000  30478.000000  30478.000000
# mean   1.273171e+07                   65.959545  10538.317311      1.525822
# std    1.190270e+07                   41.159856   1155.640036      1.017148
# min    5.000000e+02                    0.000000      0.000000      0.000000
# 25%    2.701298e+06                    0.000000  10016.000000      1.000000
# 50%    8.551693e+06                   90.000000  10065.000000      1.000000
# 75%    2.120617e+07                   95.000000  11216.000000      2.000000
# max    4.303307e+07                  100.000000  99135.000000     16.000000
#
#        Number of Records  Number Of Reviews         Price  \
# count            30478.0       30478.000000  30478.000000
# mean                 1.0          12.018735    163.589737
# std                  0.0          21.980703    197.785454
# ...

# %%
coloumn_name = data.columns
coloumn_name
# Out:
# Index(['Host Id', 'Host Since', 'Name', 'Neighbourhood ', 'Property Type',
#        'Review Scores Rating (bin)', 'Room Type', 'Zipcode', 'Beds',
#        'Number of Records', 'Number Of Reviews', 'Price',
#        'Review Scores Rating'],
#       dtype='object')

# %%
Name_price = data.groupby("Room Type")["Price"].sum().sort_values(ascending=True)
Name_price
# Out:
# Room Type
# Shared room          68035
# Private room       1159016
# Entire home/apt    3758837
# Name: Price, dtype: int64

# %%
Name_zipcode = data.groupby("Name")["Zipcode"].sum()
Name_zipcode
# Out:
# Name
# 1                                      11206.0
#      NYC, Manhattan, NY, UES B COZY    10128.0
#   3 bedroom DUPLEX, great location!    11217.0
#  $95/USD  Eat, Sleep & Explore NYC!    11205.0
#  1BR in charming 2BR, Clinton Hill     11238.0
#                                         ...
# 近地铁及市中心,交通方便,干净,明亮,到曼哈頓只要30分鐘          11355.0
# 近地铁及市中心,干净 NYC 30 min to Manhattan     11355.0
# 静 Quiet Room On Upper East Side NYC    10128.0
# 뉴욕 퀸즈, 베이사이드, 롱아일랜드 중,고교 홈스테이원합니다.     11364.0
# 맨하튼 타임스퀘어광장과 지하철 5개라인 5분거리             10018.0
# Name: Zipcode, Length: 29416, dtype: float64

# %%
Table = pd.pivot_table(data,
                       values = "Price",
                       index = "Name",
                       aggfunc = "sum")

# %%
Table = pd.pivot_table(
    data = data,
    columns = "Property Type",
    values = ["Zipcode","Price"],
    index = ["Name","Room Type"],
    aggfunc = ["sum","count","mean"],
    margins = True,
    margins_name = "ToTal"
    )

# %%
Table
# Out:
#                                                        sum             \
#                                                      Price
# Property Type                                            0  Apartment
# Name                                Room Type
# 1                                   Private room       NaN        NaN
#      NYC, Manhattan, NY, UES B COZY Entire home/apt    NaN      250.0
#   3 bedroom DUPLEX, great location! Entire home/apt    NaN      395.0
#  $95/USD  Eat, Sleep & Explore NYC! Entire home/apt    NaN       95.0
#  1BR in charming 2BR, Clinton Hill  Private room       NaN       74.0
# ...                                                    ...        ...
# 近地铁及市中心,干净 NYC 30 min to Manhattan  Private room       NaN        NaN
# 静 Quiet Room On Upper East Side NYC Private room       NaN       90.0
# 뉴욕 퀸즈, 베이사이드, 롱아일랜드 중,고교 홈스테이원합니다.  Private room       NaN        NaN
# 맨하튼 타임스퀘어광장과 지하철 5개라인 5분거리          Private room       NaN      120.0
# ...

# %%
# Pie chart
data_2 =data.head(5)
Name_price = data_2.groupby("Name")["Price"].sum()
Name_price.plot(kind = "pie")
plt.title("Name with price")
# Out:
# Text(0.5, 1.0, 'Name with price')
